# %% [markdown]
# # Condicionales

# %% [markdown]
# **if - else**
# ![IF-ELSE.PNG](attachment:IF-ELSE.PNG)

# %%
edad = int(input("¿Cuál es su edad?"))

if edad < 18:
    print("Usted es menor de edad")
else:
    print("Usted es mayor de edad")
# Out:
# ¿Cuál es su edad?3
# Usted es menor de edad

# %%
def valor_absoluto(x):
    if x >= 0:
        valor = x
    else:
        valor = -x
    return valor

x = float(input("Ingrese un número real x: "))
valor_abs = valor_absoluto(x)
print("El valor absoluto de " + str(x), end = " ")
print("es " + str(valor_abs))
# Out:
# Ingrese un número real x: 23
# El valor absoluto de 23.0 es 23.0

# %% [markdown]
# **enlazado (elif)**
# ![ELIF.PNG](attachment:ELIF.PNG)

# %%
# Edad en montaña rusa
edad = int(input("¿Cuál es su edad?"))


if edad < 18:
    print("Usted es menor de edad y no puede entrar")
elif edad > 80:
    print("Usted es mayor de edad y no puede entrar por posibles problemas en el corazón")
else:
    print("Usted es mayor de edad y está en edad para entrar")
# Out:
# ¿Cuál es su edad?2
# Usted es menor de edad y no puede entrar

# %% [markdown]
# Una tienda tiene las siguientes promociones
#
# >Si un cliente lleva más de 5 productos del mismo tipo le realizan un descuento del 5%. Si lleva más de 10 productos del
# mismo tipo le realizan un descuento del 10%. Si lleva más de 20
# productos del mismo tipo le realizan un descuento del 20%.
# Construya un programa que dado el número de productos y el
# precio de cada producto determine el valor a pagar por el cliente.

# %%
def pago_final(n, precio):
    if n <= 5:
        valor = n * precio
    elif 5 < n <= 10:
        valor = n * precio * 0.95
    elif 10 < n <= 20:
        valor = n * precio * 0.90
    else:
        valor = n * precio * 0.80
    return valor

# %%
pago_final(8,10000)
# Out:
# 76000.0

# %% [markdown]
# ## Estructuras cíclicas

# %% [markdown]
# **while (mientras)**
#
# Se ejecuta mientras la expresión booleana se cumpla (True).
#
# ![WHILE.PNG](attachment:WHILE.PNG)

# %%
Edad = 0

while(Edad < 18):
    print("Usted cree en Papa Noel")
    Edad += 3
# Out:
# Usted cree en Papa Noel
# Usted cree en Papa Noel
# Usted cree en Papa Noel
# Usted cree en Papa Noel
# Usted cree en Papa Noel
# Usted cree en Papa Noel

# %%
i = 0
while(i <= 6):
    print(i)
    i = i + 1 # i += 1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
i = 2
j = 25 
while i < j: 
    print(i, j, sep = ", ")  
    i *= 2
    j += 10 
print("the end.") 
print(i, j, sep = ", ") # valores finales de i y j
# Out:
# 2, 25
# 4, 35
# 8, 45
# 16, 55
# 32, 65
# 64, 75
# the end.
# 128, 85

# %%
# Uso de banderas #

sumafinal = 0
bandera = True
print("Bienvenido a la sumatoria de Python")
print("Nota: cuando la persona ingrese 0 se finaliza la suma")

while(bandera):
    x = float(input("Inserte un número para sumar"))
    if x == 0:
        bandera = False
    else:
        sumafinal += x
        
print(sumafinal)
# Out:
# Bienvenido a la sumatoria de Python
# Nota: cuando la persona ingrese 0 se finaliza la suma
# Inserte un número para sumar0
# 0

# %% [markdown]
# **for (para)**
# Para iterar sobre los elementos de una colección de elementos.

# %%
frutas = ["Tomate de árbol", "Maracuyá ", "Guayaba"]
for i in frutas: 
    print(i)
# Out:
# Tomate de árbol
# Maracuyá
# Guayaba

# %%
# Range(C,F,I) Cominzo, Final (no se incluye), Incremento/decremento

for f in range(2,13,2):
    print(f)
# Out:
# 2
# 4
# 6
# 8
# 10
# 12

# %% [markdown]
# # MCO

# %%
import numpy as np
import pandas as pd 
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

# %%
datos= pd.read_csv("C:/Users/57317/Desktop/Universidad Nacional/Programación/Python/Curso Econometría básica con Python/Bases de datos/GujaratiPorter71.txt", delimiter="\t")

# %%
datos.head()
# Out:
#     CM  FLR  PGNP   TFR
# 0  128   37  1870  6.66
# 1  204   22   130  6.15
# 2  202   16   310  7.00
# 3  197   65   570  6.25
# 4   96   76  2050  3.81

# %%
fig, ax = plt.subplots() # Se ponen dos nombres hay una figura y dentro un ax (otra)
ax.scatter(datos["PGNP"],datos["CM"])
ax.set_xlabel("PNB per cápita")
ax.set_ylabel("Mortalidad infantil")
ax.set_title("Relación", fontsize = 15, color="black")
plt.show()

# %%
Modelo=sm.OLS(datos["CM"], datos["PGNP"]) #Primero y después x
Resultados = Modelo.fit()
print(Resultados.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                     CM   R-squared (uncentered):                   0.056
# Model:                            OLS   Adj. R-squared (uncentered):              0.041
# Method:                 Least Squares   F-statistic:                              3.710
# Date:                Mon, 03 May 2021   Prob (F-statistic):                      0.0586
# Time:                        20:11:21   Log-Likelihood:                         -413.92
# No. Observations:                  64   AIC:                                      829.8
# Df Residuals:                      63   BIC:                                      832.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
Modelo2=sm.OLS(datos["CM"],sm.add_constant(datos["PGNP"])) #Primero y después x
Resultados2 = Modelo2.fit()
print(Resultados2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     CM   R-squared:                       0.166
# Model:                            OLS   Adj. R-squared:                  0.153
# Method:                 Least Squares   F-statistic:                     12.36
# Date:                Mon, 03 May 2021   Prob (F-statistic):           0.000826
# Time:                        20:11:21   Log-Likelihood:                -361.64
# No. Observations:                  64   AIC:                             727.3
# Df Residuals:                      62   BIC:                             731.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        157.4244      9.846     15.989      0.000     137.743     177.105
# ...

# %%
Valores_estimados = Resultados2.predict()

# %%
fig, ax = plt.subplots()
ax.scatter(datos["PGNP"],datos["CM"], color="blue")
ax.scatter(datos["PGNP"],Valores_estimados, color="red")
ax.set_xlabel("PNB per capita")
ax.set_ylabel("Mortalidad Infantil")
ax.set_title("Relación", fontsize = 15, color="black")
plt.show()

# %%
datos["1/PGNP"] = 1/datos["PGNP"]

# %%
datos.head()
# Out:
#     CM  FLR  PGNP   TFR    1/PGNP
# 0  128   37  1870  6.66  0.000535
# 1  204   22   130  6.15  0.007692
# 2  202   16   310  7.00  0.003226
# 3  197   65   570  6.25  0.001754
# 4   96   76  2050  3.81  0.000488

# %%
Modelo3= sm.OLS(datos["CM"], sm.add_constant(datos["1/PGNP"]))
Resultados3 = Modelo3.fit()
print(Resultados3.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     CM   R-squared:                       0.459
# Model:                            OLS   Adj. R-squared:                  0.450
# Method:                 Least Squares   F-statistic:                     52.61
# Date:                Mon, 03 May 2021   Prob (F-statistic):           7.82e-10
# Time:                        20:11:22   Log-Likelihood:                -347.79
# No. Observations:                  64   AIC:                             699.6
# Df Residuals:                      62   BIC:                             703.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         81.7944     10.832      7.551      0.000      60.141     103.447
# ...

# %%
Valores_estimados3 = Resultados3.predict()

# %%
fig, ax = plt.subplots()
ax.scatter(datos["PGNP"], datos["CM"], color = "blue")
ax.scatter(datos["PGNP"], Valores_estimados3, color = "red")
ax.set_xlabel("1 / PNB per capita")
ax.set_ylabel("Mortalidad Infantil")
ax.set_title("Relacion", fontsize = 15, color="black")
plt.show()

# %%
grafico = sns.pairplot(data = datos, y_vars = "CM", diag_kind="kde")

# %%
Y = datos["CM"]
X = datos[["PGNP", "FLR"]]

# %%
Modelo4 = sm.OLS(Y, sm.add_constant(X))
Resultados4 = Modelo4.fit()
print(Resultados4.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     CM   R-squared:                       0.708
# Model:                            OLS   Adj. R-squared:                  0.698
# Method:                 Least Squares   F-statistic:                     73.83
# Date:                Mon, 03 May 2021   Prob (F-statistic):           5.12e-17
# Time:                        20:11:24   Log-Likelihood:                -328.10
# No. Observations:                  64   AIC:                             662.2
# Df Residuals:                      61   BIC:                             668.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        263.6416     11.593     22.741      0.000     240.460     286.824
# ...

# %%
Valores_estimados4 = Resultados4.predict()

# %%
dir(Resultados4) #Todos los métodos o atributos que se pueden aplicar al objeto
# Out:
# ['HC0_se',
#  'HC1_se',
#  'HC2_se',
#  'HC3_se',
#  '_HCCM',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abat_diagonal',
#  '_cache',
#  '_data_attr',
#  '_data_in_cache',
#  '_get_robustcov_results',
#  '_is_nested',
#  '_use_t',
#  '_wexog_singular_values',
#  'aic',
#  'bic',
#  'bse',
#  'centered_tss',
#  'compare_f_test',
#  'compare_lm_test',
#  'compare_lr_test',
#  'condition_number',
#  'conf_int',
#  'conf_int_el',
#  'cov_HC0',
#  'cov_HC1',
#  'cov_HC2',
#  'cov_HC3',
#  'cov_kwds',
#  'cov_params',
#  'cov_type',
#  'df_model',
#  'df_resid',
#  'diagn',
#  'eigenvals',
#  'el_test',
# ...

# %%
fig, ax = plt.subplots()
ax.scatter(datos["PGNP"], datos["CM"], color = "blue")
ax.scatter(datos["PGNP"], Valores_estimados4, color = "red")
ax.set_xlabel("PNB per capita")
ax.set_ylabel("Mortalidad Infantil")
ax.set_title("Relacion", fontsize = 15, color="black")
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(datos["FLR"], datos["CM"], color = "blue")
ax.scatter(datos["FLR"], Valores_estimados4, color = "red")
ax.set_xlabel("FLR")
ax.set_ylabel("Mortalidad Infantil")
ax.set_title("Relacion", fontsize = 15, color="black")
plt.show()

# %%
Resultados_robustos = Resultados4.get_robustcov_results()
print(Resultados_robustos.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     CM   R-squared:                       0.708
# Model:                            OLS   Adj. R-squared:                  0.698
# Method:                 Least Squares   F-statistic:                     93.06
# Date:                Mon, 03 May 2021   Prob (F-statistic):           2.94e-19
# Time:                        20:11:36   Log-Likelihood:                -328.10
# No. Observations:                  64   AIC:                             662.2
# Df Residuals:                      61   BIC:                             668.7
# Df Model:                           2
# Covariance Type:                  HC1
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        263.6416     11.983     22.002      0.000     239.681     287.602
# ...

# %% [markdown]
# ### Stargazer

# %%
# !pip install stargazer
# Out:
# ^C

# %%
from stargazer.stargazer import Stargazer

# %%
tabla = Stargazer([Resultados4])

# %%
print(Stargazer([Resultados4]).render_latex())
# Out:
# \begin{table}[!htbp] \centering
# \begin{tabular}{@{\extracolsep{5pt}}lc}
# \\[-1.8ex]\hline
# \hline \\[-1.8ex]
# & \multicolumn{1}{c}{\textit{Dependent variable:}} \
# \cr \cline{1-2}
# \\[-1.8ex] & (1) \\
# \hline \\[-1.8ex]
#  FLR & -2.232$^{***}$ \\
#   & (0.210) \\
#  PGNP & -0.006$^{***}$ \\
#   & (0.002) \\
#  const & 263.642$^{***}$ \\
#   & (11.593) \\
# \hline \\[-1.8ex]
#  Observations & 64 \\
#  $R^2$ & 0.708 \\
#  Adjusted $R^2$ & 0.698 \\
#  Residual Std. Error & 41.748(df = 61)  \\
#  F Statistic & 73.833$^{***}$ (df = 2.0; 61.0) \\
# \hline
# \hline \\[-1.8ex]
# \textit{Note:} & \multicolumn{1}{r}{$^{*}$p$<$0.1; $^{**}$p$<$0.05; $^{***}$p$<$0.01} \\
# \end{tabular}
# \end{table}

# %%
tabla.title("Resultados Modelo")

# %%
tabla
# Out:
# Resultados Modelo<br><table style="text-align:center"><tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"></td><td colspan="1"><em>Dependent variable:CM</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td></tr><tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">FLR</td><td>-2.232<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(0.210)</td></tr><tr><td style="text-align:left">PGNP</td><td>-0.006<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(0.002)</td></tr><tr><td style="text-align:left">const</td><td>263.642<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(11.593)</td></tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Observations</td><td>64</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.708</td></tr><tr><td style="text-
# ...

# %%
print(Stargazer([Resultados3,Resultados4]).render_latex())
# Out:
# \begin{table}[!htbp] \centering
# \begin{tabular}{@{\extracolsep{5pt}}lcc}
# \\[-1.8ex]\hline
# \hline \\[-1.8ex]
# & \multicolumn{2}{c}{\textit{Dependent variable:}} \
# \cr \cline{2-3}
# \\[-1.8ex] & (1) & (2) \\
# \hline \\[-1.8ex]
#  1/PGNP & 27273.165$^{***}$ & \\
#   & (3759.999) & \\
#  FLR & & -2.232$^{***}$ \\
#   & & (0.210) \\
#  PGNP & & -0.006$^{***}$ \\
#   & & (0.002) \\
#  const & 81.794$^{***}$ & 263.642$^{***}$ \\
#   & (10.832) & (11.593) \\
# \hline \\[-1.8ex]
#  Observations & 64 & 64 \\
#  $R^2$ & 0.459 & 0.708 \\
#  Adjusted $R^2$ & 0.450 & 0.698 \\
#  Residual Std. Error & 56.330(df = 62) & 41.748(df = 61)  \\
#  F Statistic & 52.613$^{***}$ (df = 1.0; 62.0) & 73.833$^{***}$ (df = 2.0; 61.0) \\
# \hline
# \hline \\[-1.8ex]
# \textit{Note:} & \multicolumn{2}{r}{$^{*}$p$<$0.1; $^{**}$p$<$0.05; $^{***}$p$<$0.01} \\
# \end{tabular}
# \end{table}
